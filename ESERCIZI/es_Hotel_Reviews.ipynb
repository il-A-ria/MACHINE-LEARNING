# %%
# !wget https://frenzy86.s3.eu-west-2.amazonaws.com/python/Hotel_Reviews_Jun19.csv
# Out:
# --2022-04-01 13:17:21--  https://frenzy86.s3.eu-west-2.amazonaws.com/python/Hotel_Reviews_Jun19.csv
# Resolving frenzy86.s3.eu-west-2.amazonaws.com (frenzy86.s3.eu-west-2.amazonaws.com)... 52.95.149.142
# Connecting to frenzy86.s3.eu-west-2.amazonaws.com (frenzy86.s3.eu-west-2.amazonaws.com)|52.95.149.142|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 124452060 (119M) [text/csv]
# Saving to: ‘Hotel_Reviews_Jun19.csv’
#
# Hotel_Reviews_Jun19 100%[===================>] 118.69M  97.1MB/s    in 1.2s
#
# 2022-04-01 13:17:22 (97.1 MB/s) - ‘Hotel_Reviews_Jun19.csv’ saved [124452060/124452060]

# %%
import matplotlib.pyplot as plt

# %%
plt.
plt.axis('off')
