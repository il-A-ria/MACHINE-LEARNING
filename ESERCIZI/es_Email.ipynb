# %% [markdown]
# Estrarre dalla colonna content le email. Nella campagna ogni email costa 1 euro. Quanto costa la campagna?

# %%
#[a-z]

# %%
import pandas as pd

# %%
# !wget https://frenzy86.s3.eu-west-2.amazonaws.com/IFAO/email_re.xlsx
# Out:
# --2022-03-29 14:36:05--  https://frenzy86.s3.eu-west-2.amazonaws.com/IFAO/email_re.xlsx
# Resolving frenzy86.s3.eu-west-2.amazonaws.com (frenzy86.s3.eu-west-2.amazonaws.com)... 52.95.148.170
# Connecting to frenzy86.s3.eu-west-2.amazonaws.com (frenzy86.s3.eu-west-2.amazonaws.com)|52.95.148.170|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 339422 (331K) [application/vnd.openxmlformats-officedocument.spreadsheetml.sheet]
# Saving to: ‘email_re.xlsx’
#
# email_re.xlsx       100%[===================>] 331.47K  1.03MB/s    in 0.3s
#
# 2022-03-29 14:36:06 (1.03 MB/s) - ‘email_re.xlsx’ saved [339422/339422]

# %%
df = pd.read_excel('email_re.xlsx')

# %%
#per trasformare una colonna in una lista ----> to list

# %%
df_list = list(df["content"])
