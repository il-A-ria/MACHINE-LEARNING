# %%
# !wget https://frenzy86.s3.eu-west-2.amazonaws.com/fav/ai-machine/nlp/reviews_feb2019.csv
# Out:
# --2022-04-01 10:20:35--  https://frenzy86.s3.eu-west-2.amazonaws.com/fav/ai-machine/nlp/reviews_feb2019.csv
# Resolving frenzy86.s3.eu-west-2.amazonaws.com (frenzy86.s3.eu-west-2.amazonaws.com)... 52.95.149.10
# Connecting to frenzy86.s3.eu-west-2.amazonaws.com (frenzy86.s3.eu-west-2.amazonaws.com)|52.95.149.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15206 (15K) [application/vnd.ms-excel]
# Saving to: ‘reviews_feb2019.csv’
#
# reviews_feb2019.csv 100%[===================>]  14.85K  --.-KB/s    in 0s
#
# 2022-04-01 10:20:36 (125 MB/s) - ‘reviews_feb2019.csv’ saved [15206/15206]

# %%
import pandas as pd
import re

# %%
df = pd.read_csv('reviews_feb2019')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-635b185928fe> in <module>()
# ----> 1 df = pd.read_csv('reviews_feb2019')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %% [markdown]
# la lungh può essere una correlazione importante

# %%
#come faccio a creare una colonna che mi dice la lungh del testo?
#creo una nuova colonna

# %%
reviews_text.map(len)

# %%
#lungh per ogni row
#lo metto sotto forma di colonna

# %%
new_reviews.groupby(['Star Rating']).count()

# %%
new_reviews.mean()
