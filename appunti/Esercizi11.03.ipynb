# %%
def sommaduenum(x,y):

  ris = x+y
  return ris

# %%
somma = sommaduenum(-150,100)
somma
# Out:
# -50

# %%
def posneg(x):
  if x<0:
      return 'il num è neg'
  elif x==0:
      return 'il num inserito è zero, cambiare num'
  else:
      return 'il num è pos'

# %%
x = float(input("inserire numero: "))
if x<0:
      print ('il num è neg')
elif x==0:
      print ('il num inserito è zero, cambiare num')
else:
      print('il num è pos')
# Out:
# inserire numero: -23
# il num è neg

# %%
#funzione per capire se il num è pari o dispari

# %%
def pari_o_disp(x):
  if x%2==0:
    return 'il num è pari'
  else:
    return 'il num è dispari'

# %%
x = float(input("inserisci numero: "))
print(pari_o_disp(x))
# Out:
# inserisci numero: 23
# il num è dispari

# %%
def pari_dispari(x):     #versione prof
  resto=x%2
  if resto == 0: 
    return 'il num è pari'
  else:
    return 'il num è dispari'

# %%
pari_dispari()

# %%
# %%writefile formulario.py

def area_triang(b,h):
  areat = b*h/2
  return areat

#area del cerchio
def area_cerchio(r):
  areac = r**2 * 3.14
  return areac

#perimetro triangolo
def perimetro_tr(x,y,z):
  perim = x + y + z
  return perim
# Out:
# Overwriting formulario.py

# %%
area_triang(20,5)
# Out:
# 50.0

# %%
print("l'area del triangolo é: ", area_triang(20,5))
# Out:
# l'area del triangolo é:  50.0

# %%
from formulario import area_triang as at

# %%
at(4,7)
# Out:
# 14.0

# %%
# %%writefile formulario.py
#area del cerchio
def area_cerchio(r):
  areac = r**2 * 3.14
  return areac
# Out:
# Overwriting formulario.py

# %%
print(area_cerchio(4))
# Out:
# 50.24

# %%
# %%writefile formulario.py
#perimetro triangolo
def perimetro_tr(x,y,z):
  perim = x + y + z
  return perim
# Out:
# Overwriting formulario.py

# %%
print(perimetro_tr(3,6,3))
# Out:
# 12

# %%
from formulario import area_cerchio

# %%
ls
# Out:
# drive/  formulario.py  __pycache__/  sample_data/

# %%
cd /content/drive/MyDrive/Colab Notebooks/esercitazioni
# Out:
# /content/drive/MyDrive/Colab Notebooks/esercitazioni

# %%
ls
# Out:
#  1-37-768x512.jpg                                 Esercizi11.03.ipynb
# 'Copia di Copia di Un benvenuto a Colaboratory'   formulario.py
# 'Copia di Untitled0.ipynb'                       'Mining03-04 104205.png'
#  Esercitazione01.ipynb

# %%
cd /content/drive/MyDrive/Colab Notebooks/esercitazioni
# Out:
# /content/drive/MyDrive/Colab Notebooks/esercitazioni

# %%
# %%writefile formulario.py

def area_triang(b,h):
  areat = b*h/2
  return areat

#area del cerchio
def area_cerchio(r):
  areac = r**2 * 3.14
  return areac

#perimetro triangolo
def perimetro_tr(x,y,z):
  perim = x + y + z
  return perim

#perimetro triangolo
def perimetro_cer(r)

#perimetro triangolo
def perimetro_cer(r):
  percer = (2 * r) * 3.14
  return percer
# Out:
# Overwriting formulario.py

# %%
#perimetro triangolo
def perimetro_cer(r):
  percer = (2 * r) * 3.14
  return percer

# %%
print(perimetro_cer(4))
# Out:
# 25.12
