# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
# !wget  https://frenzy86.s3.eu-west-2.amazonaws.com/python/data/esercizi/audit.csv
# Out:
# --2022-03-22 11:18:20--  https://frenzy86.s3.eu-west-2.amazonaws.com/python/data/esercizi/audit.csv
# Resolving frenzy86.s3.eu-west-2.amazonaws.com (frenzy86.s3.eu-west-2.amazonaws.com)... 52.95.150.90
# Connecting to frenzy86.s3.eu-west-2.amazonaws.com (frenzy86.s3.eu-west-2.amazonaws.com)|52.95.150.90|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39965 (39K) [text/csv]
# Saving to: ‘audit.csv.1’
#
# audit.csv.1         100%[===================>]  39.03K  --.-KB/s    in 0.1s
#
# 2022-03-22 11:18:21 (289 KB/s) - ‘audit.csv.1’ saved [39965/39965]

# %% [markdown]
# ###step 0:
# carico dataset e definizione del tipo di problema(classification o regression)?
#
# -- chi è la target?

# %%
df = pd.read_csv('audit.csv')
df
# Out:
#      Sector_score LOCATION_ID  PARA_A  SCORE_A  PARA_B  SCORE_B  TOTAL  \
# 0            3.89          23    4.18        6    2.50        2   6.68
# 1            3.89           6    0.00        2    4.83        2   4.83
# 2            3.89           6    0.51        2    0.23        2   0.74
# 3            3.89           6    0.00        2   10.80        6  10.80
# 4            3.89           6    0.00        2    0.08        2   0.08
# ..            ...         ...     ...      ...     ...      ...    ...
# 771         55.57           9    0.49        2    0.40        2   0.89
# 772         55.57          16    0.47        2    0.37        2   0.84
# 773         55.57          14    0.24        2    0.04        2   0.28
# 774         55.57          18    0.20        2    0.00        2   0.20
# 775         55.57          15    0.00        2    0.00        2   0.00
#
#      numbers  Marks  Money_Value  MONEY_Marks  District  Loss  LOSS_SCORE  \
# ...

# %%
#vediamo che è un problema di classificazione binario da Risk(1,0)

# %% [markdown]
# STEP 1

# %%
df.describe().T
# Out:
#                count       mean        std   min     25%    50%      75%  \
# Sector_score   776.0  20.184536  24.319017  1.85  2.3700  3.890  55.5700
# PARA_A         776.0   2.450194   5.678870  0.00  0.2100  0.875   2.4800
# SCORE_A        776.0   3.512887   1.740549  2.00  2.0000  2.000   6.0000
# PARA_B         776.0  10.799988  50.083624  0.00  0.0000  0.405   4.1600
# SCORE_B        776.0   3.131443   1.698042  2.00  2.0000  2.000   4.0000
# TOTAL          776.0  13.218481  51.312829  0.00  0.5375  1.370   7.7075
# numbers        776.0   5.067655   0.264449  5.00  5.0000  5.000   5.0000
# Marks          776.0   2.237113   0.803517  2.00  2.0000  2.000   2.0000
# Money_Value    775.0  14.137631  66.606519  0.00  0.0000  0.090   5.5950
# MONEY_Marks    776.0   2.909794   1.597452  2.00  2.0000  2.000   4.0000
# District       776.0   2.505155   1.228678  2.00  2.0000  2.000   2.0000
# Loss           776.0   0.029639   0.184280  0.00  0.0000  0.000   0.0000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 776 entries, 0 to 775
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sector_score   776 non-null    float64
#  1   LOCATION_ID    776 non-null    object
#  2   PARA_A         776 non-null    float64
#  3   SCORE_A        776 non-null    int64
#  4   PARA_B         776 non-null    float64
#  5   SCORE_B        776 non-null    int64
#  6   TOTAL          776 non-null    float64
#  7   numbers        776 non-null    float64
#  8   Marks          776 non-null    int64
#  9   Money_Value    775 non-null    float64
#  10  MONEY_Marks    776 non-null    int64
#  11  District       776 non-null    int64
#  12  Loss           776 non-null    int64
#  13  LOSS_SCORE     776 non-null    int64
#  14  History        776 non-null    int64
#  15  History_score  776 non-null    int64
#  16  Score          776 non-null    float64
# ...

# %%
#LOCATION_ID è una stringa, quindi abbiamo un problema!protremmo modificarla e trasformarla in numero, ma in questo caso non si può, quindi andremo ad eliminarla. 
#in generale ID non è molto importante per l'analisi

# %%
#df['LOCATION_ID] = df['LOCATION_ID].astype(float)     
#print(df:dtypes)

# %% [markdown]
# andiamo a controllare i valori nulli

# %%
df.isnull().sum()
# Out:
# Sector_score     0
# LOCATION_ID      0
# PARA_A           0
# SCORE_A          0
# PARA_B           0
# SCORE_B          0
# TOTAL            0
# numbers          0
# Marks            0
# Money_Value      1
# MONEY_Marks      0
# District         0
# Loss             0
# LOSS_SCORE       0
# History          0
# History_score    0
# Score            0
# Risk             0
# dtype: int64

# %%
df.dropna()     #elimino i valori nulli
# Out:
#      Sector_score LOCATION_ID  PARA_A  SCORE_A  PARA_B  SCORE_B  TOTAL  \
# 0            3.89          23    4.18        6    2.50        2   6.68
# 1            3.89           6    0.00        2    4.83        2   4.83
# 2            3.89           6    0.51        2    0.23        2   0.74
# 3            3.89           6    0.00        2   10.80        6  10.80
# 4            3.89           6    0.00        2    0.08        2   0.08
# ..            ...         ...     ...      ...     ...      ...    ...
# 771         55.57           9    0.49        2    0.40        2   0.89
# 772         55.57          16    0.47        2    0.37        2   0.84
# 773         55.57          14    0.24        2    0.04        2   0.28
# 774         55.57          18    0.20        2    0.00        2   0.20
# 775         55.57          15    0.00        2    0.00        2   0.00
#
#      numbers  Marks  Money_Value  MONEY_Marks  District  Loss  LOSS_SCORE  \
# ...

# %%
df['Risk'].value_counts()     #Risk è la nostra target (y). se il rapporto sulle classi è sotto il 20% 
#                              è un problema!perchè non sono bilanciate e non sono abbastanza per risolvere il problema.
# Out:
# 1    486
# 0    290
# Name: Risk, dtype: int64

# %% [markdown]
# 0 -> No Risk
#
# 1 -> Risk

# %%
df.groupby('Risk').mean()
# Out:
#       Sector_score    PARA_A   SCORE_A     PARA_B   SCORE_B      TOTAL  \
# Risk
# 0        31.969793  0.301793  2.000000   0.251038  2.000000   0.552831
# 1        13.152181  3.732162  4.415638  17.094630  3.806584  20.776174
#
#        numbers     Marks  Money_Value  MONEY_Marks  District      Loss  \
# Risk
# 0     5.000000  2.000000     0.264754     2.000000  2.000000  0.000000
# 1     5.108025  2.378601    22.387140     3.452675  2.806584  0.047325
#
#       LOSS_SCORE   History  History_score     Score
# Risk
# 0       2.000000  0.000000        2.00000  2.000000
# 1       2.098765  0.166667        2.26749  3.121811

# %% [markdown]
# EDA

# %% [markdown]
# CORRELATION MATRIX

# %%
import seaborn as sns

# %%
corr_matrix = df.corr()    #matrice di correlazione

plt.figure(figsize=(10,9))
sns.heatmap(corr_matrix)     
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
sns.pairplot(df, hue='class', height=3, aspect=1);
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'class'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
X = df.drop(['Risk','LOCATION_ID']), axis = 1
y = df['Risk']
